# %% [markdown]
# # **What is a Flash Alert in Flask?**

# %% [markdown]
# **A flash alert in Flask is a way to show temporary messages to the user, such as success messages, warnings, or errors. These messages disappear after the user reloads or moves to a new page.**

# %% [markdown]
# # **Example of Flash Alert**
#
# **Imagine a login system:**
#
# User enters correct login details → Show message:
#
# ✅ "You have successfully logged in!"
#
# User tries to log in again while already logged in → Show message:
#
# ⚠️ "You are already logged in!"
#
# User logs out → Show message:
#
# 🔴 "You have successfully logged out!"
#
# These messages only appear once and disappear after the next page load.

# %% [markdown]
# ![Screenshot 2025-02-04 160020.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-04 160039.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-04 160049.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-04 160057.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-04 160226.png](data:image/png;base64,...)
